# %%
# Adding more intents and responses
intents.append({
    "tag": "thanks",
    "patterns": ["Thank you", "Thanks", "Thanks a lot", "I appreciate it"],
    "responses": ["You're welcome", "No problem", "Glad I could help"]
})

intents.append({
    "tag": "about",
    "patterns": ["What can you do", "Who are you", "What are you", "What is your purpose"],
    "responses": ["I am a chatbot", "My purpose is to assist you", "I can answer questions and provide assistance"]
})

# Updating the classifier to handle new intents
tags = []
patterns = []

for i in intents:
    for pattern in i['patterns']:
        tags.append(i['tag'])
        patterns.append(pattern)

x = vectoriser.fit_transform(patterns)
y = tags

classifier.fit(x in patterns)
y = tags
classifier.fit(x, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3970441592.py in <cell line: 0>()
#       1 # Adding more intents and responses
# ----> 2 intents.append({
#       3     "tag": "thanks",
#       4     "patterns": ["Thank you", "Thanks", "Thanks a lot", "I appreciate it"],
#       5     "responses": ["You're welcome", "No problem", "Glad I could help"]
#
# NameError: name 'intents' is not defined
