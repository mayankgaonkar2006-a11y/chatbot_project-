# %%
import nltk
import random
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
intents = [
    {
        "tag": "greeting",
        "patterns": ["Hi", "Hello", "Hey", "How are you", "What's up"],
        "responses": ["Hi there", "Hello", "Hey", "I'm fine, thank you", "Nothing much"]
    },
    {
        "tag": "goodbye",
        "patterns": ["Bye", "See you later", "Goodbye", "Take care"],
        "responses": ["Goodbye", "See you later", "Take care"]
    }
]

# %%
vectoriser = TfidfVectorizer()
tags = []
patterns = []

for i in intents:
    for pattern in i['patterns']:
        tags.append(i['tag'])
        patterns.append(pattern)

# %%
x = vectoriser.fit_transform(patterns)
y = tags

# %%
classifier = LogisticRegression(random_state=0, max_iter=10000)
classifier.fit(x, y)

def chatbox_response(text):
    input_text = vectoriser.transform([text])
    tags = classifier.predict(input_text)[0]
    for i in intents:
        if i['tag'] == tags:
            response = random.choice(i['responses'])
            return response

# %%
while True:
    query = input("User--> ")
    output = chatbox_response(query)
    print("Chatbox->{}".format(output))
# Out:
# User--> hello
# Chatbox->Nothing much
